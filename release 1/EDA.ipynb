# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/real_estate/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/users/danilabalakin/Downloads/_data.csv')
df
# Out:
#        Unnamed: 0  ID  объявления Количество комнат       Тип  \
# 0               0       271271157                 4  Квартира
# 1               1       271634126                 4  Квартира
# 2               2       271173086   4, Оба варианта  Квартира
# 3               3       272197456   4, Оба варианта  Квартира
# 4               4       273614615                 2  Квартира
# ...           ...             ...               ...       ...
# 23363       23363       215565511               NaN  Квартира
# 23364       23364       274654844                 1  Квартира
# 23365       23365       268679909   2, Оба варианта  Квартира
# 23366       23366       274807525                 2  Квартира
# 23367       23367       274672243   2, Оба варианта  Квартира
#
#                               Метро  \
# 0      м. Смоленская (9 мин пешком)
# 1      м. Смоленская (8 мин пешком)
# 2      м. Смоленская (7 мин пешком)
# 3      м. Смоленская (3 мин пешком)
# 4       м. Арбатская (7 мин пешком)
# ...                             ...
# 23363    м. Говорово (8 мин пешком)
# 23364    м. Солнцево (7 мин пешком)
# 23365    м. Солнцево (6 мин пешком)
# 23366   м. Солнцево (11 мин пешком)
# 23367   м. Говорово (10 мин пешком)
#
#                                                    Адрес      Площадь, м2  \
# 0                          Москва, улица Новый Арбат, 27       200.0/20.0
# 1                          Москва, улица Новый Арбат, 27  198.0/95.0/18.0
# 2                          Москва, улица Новый Арбат, 27  200.0/116.0/4.0
# 3                       Москва, переулок Плотников, 21С1  170.0/95.0/17.0
# 4                          Москва, улица Новый Арбат, 15    58.0/38.0/5.0
# ...                                                  ...              ...
# 23363  Москва, Боровское шоссе, 2к7, ш. Боровское (3 ...    35.0/16.4/8.0
# 23364  Москва, Производственная улица, 8к1, ш. Боровс...   38.7/16.5/11.0
# 23365                       Москва, Боровский проезд, 11             43.1
# 23366  Москва, улица Богданова, 6к1, ш. Боровское (3 ...        52.5/10.0
# 23367  Москва, улица Богданова, 2к1, ш. Боровское (3 ...   90.0/48.2/15.5
#
#                              Дом   Парковка  \
# 0               5/16, Монолитный  подземная
# 1      5/16, Монолитно-кирпичный  подземная
# 2                           5/16  подземная
# 3                            5/6  подземная
# 4               12/26, Панельный        NaN
# ...                          ...        ...
# 23363                      10/14        NaN
# 23364           5/18, Монолитный        NaN
# 23365             5/5, Кирпичный        NaN
# 23366           8/23, Монолитный   наземная
# 23367            6/23, Панельный        NaN
#
#                                                     Цена  ...  \
# 0      500000.0 руб./ За месяц, Залог - 500000 руб., ...  ...
# 1      500000.0 руб./ За месяц, Залог - 500000 руб., ...  ...
# 2      500000.0 руб./ За месяц, Залог - 500000 руб., ...  ...
# 3      400000.0 руб./ За месяц, Залог - 400000 руб., ...  ...
# 4      225000.0 руб./ За месяц, Залог - 225000 руб., ...  ...
# ...                                                  ...  ...
# 23363  42000.0 руб./ За месяц, Залог - 42000 руб., Ко...  ...
# 23364  45000.0 руб./ За месяц, Залог - 45000 руб., Ко...  ...
# 23365  50000.0 руб./ За месяц, Залог - 50000 руб., Ко...  ...
# 23366  55000.0 руб./ За месяц, Залог - 50000 руб., Ко...  ...
# 23367  57000.0 руб./ За месяц, Залог - 60000 руб., Ко...  ...
#
#                   Окна                          Санузел  \
# 0                  NaN                              NaN
# 1      На улицу и двор  Совмещенный (2), Раздельный (1)
# 2      На улицу и двор                  Совмещенный (3)
# 3      На улицу и двор                  Совмещенный (3)
# 4      На улицу и двор                  Совмещенный (2)
# ...                ...                              ...
# 23363              NaN                  Совмещенный (1)
# 23364          Во двор                  Совмещенный (1)
# 23365  На улицу и двор                  Совмещенный (1)
# 23366          Во двор  Совмещенный (1), Раздельный (1)
# 23367          Во двор                   Раздельный (1)
#
#                 Можно с детьми/животными  \
# 0      Можно с детьми, Можно с животными
# 1                         Можно с детьми
# 2                         Можно с детьми
# 3                      Можно с животными
# 4                                    NaN
# ...                                  ...
# 23363                                NaN
# 23364                                NaN
# 23365                     Можно с детьми
# 23366                                NaN
# 23367  Можно с детьми, Можно с животными
#
#                                            Дополнительно        Название ЖК  \
# 0      Мебель в комнатах, Мебель на кухне, Ванна, Душ...  Новый Арбат, 2010
# 1      Мебель в комнатах, Мебель на кухне, Ванна, Душ...        Новый Арбат
# 2      Мебель в комнатах, Мебель на кухне, Ванна, Душ...        Новый Арбат
# 3      Мебель в комнатах, Мебель на кухне, Ванна, Душ...                NaN
# 4      Мебель в комнатах, Мебель на кухне, Ванна, Душ...           The Book
# ...                                                  ...                ...
# 23363  Мебель в комнатах, Мебель на кухне, Ванна, Сти...      Мещерский лес
# 23364  Мебель в комнатах, Мебель на кухне, Ванна, Сти...               Лучи
# 23365  Мебель на кухне, Душевая кабина, Стиральная ма...                NaN
# 23366  Мебель в комнатах, Мебель на кухне, Ванна, Сти...                NaN
# 23367  Мебель в комнатах, Мебель на кухне, Ванна, Сти...                NaN
#
#       Серия дома Высота потолков, м                Лифт Мусоропровод  \
# 0            NaN               3.00  Пасс (4), Груз (1)           Да
# 1            NaN               3.50  Пасс (1), Груз (1)          Нет
# 2            NaN               3.20            Пасс (1)          NaN
# 3            NaN               3.20            Пасс (1)          NaN
# 4            NaN               3.90  Пасс (1), Груз (1)           Да
# ...          ...                ...                 ...          ...
# 23363        NaN                NaN  Пасс (1), Груз (1)          NaN
# 23364        NaN                NaN  Пасс (1), Груз (1)          NaN
# 23365        NaN                NaN                 NaN          NaN
# 23366        NaN               2.65            Пасс (3)           Да
# 23367        NaN                NaN            Пасс (3)           Да
#
#                           Ссылка на объявление
# 0      https://www.cian.ru/rent/flat/271271157
# 1      https://www.cian.ru/rent/flat/271634126
# 2      https://www.cian.ru/rent/flat/271173086
# 3      https://www.cian.ru/rent/flat/272197456
# 4      https://www.cian.ru/rent/flat/273614615
# ...                                        ...
# 23363  https://www.cian.ru/rent/flat/215565511
# 23364  https://www.cian.ru/rent/flat/274654844
# 23365  https://www.cian.ru/rent/flat/268679909
# 23366  https://www.cian.ru/rent/flat/274807525
# 23367  https://www.cian.ru/rent/flat/274672243
#
# [23368 rows x 25 columns]

# %%
df = df.where(df.notna(), None)

# %%
df
# Out:
#        Unnamed: 0  ID  объявления Количество комнат       Тип  \
# 11             11       273999490  3, Изолированная  Квартира
# 48             48       271265359   2, Оба варианта  Квартира
# 53             53       273779074                 2  Квартира
# 80             80       274528249                 1  Квартира
# 81             81       274431438   3, Оба варианта  Квартира
# ...           ...             ...               ...       ...
# 23360       23360       274905391                 1  Квартира
# 23361       23361       202336163                 1  Квартира
# 23364       23364       274654844                 1  Квартира
# 23366       23366       274807525                 2  Квартира
# 23367       23367       274672243   2, Оба варианта  Квартира
#
#                                Метро  \
# 11      м. Смоленская (2 мин пешком)
# 48      м. Смоленская (5 мин пешком)
# 53      м. Смоленская (7 мин пешком)
# 80       м. Арбатская (3 мин пешком)
# 81      м. Смоленская (3 мин пешком)
# ...                              ...
# 23360  м. Солнцево (5 мин на машине)
# 23361    м. Солнцево (10 мин пешком)
# 23364     м. Солнцево (7 мин пешком)
# 23366    м. Солнцево (11 мин пешком)
# 23367    м. Говорово (10 мин пешком)
#
#                                                    Адрес     Площадь, м2  \
# 11                          Москва, Новинский бульвар, 7  80.0/53.0/11.0
# 48                            Москва, улица Арбат, 45/24  60.0/43.0/10.0
# 53          Москва, Большой Николопесковский переулок, 3  60.0/40.0/11.0
# 80                          Москва, Никитский бульвар, 5       45.0/38.0
# 81                       Москва, Карманицкий переулок, 3   65.0/49.0/9.0
# ...                                                  ...             ...
# 23360  Москва, Солнцевский проспект, 19, ш. Боровское...   39.0/20.0/8.0
# 23361  Москва, Солнцевский проспект, 32, ш. Боровское...   32.0/19.0/6.0
# 23364  Москва, Производственная улица, 8к1, ш. Боровс...  38.7/16.5/11.0
# 23366  Москва, улица Богданова, 6к1, ш. Боровское (3 ...       52.5/10.0
# 23367  Москва, улица Богданова, 2к1, ш. Боровское (3 ...  90.0/48.2/15.5
#
#                     Дом  Парковка  \
# 11       4/8, Кирпичный      None
# 48                  5/6  наземная
# 53       3/6, Кирпичный      None
# 80       6/7, Кирпичный  наземная
# 81                  7/7  наземная
# ...                 ...       ...
# 23360  12/17, Панельный      None
# 23361    9/9, Панельный      None
# 23364  5/18, Монолитный      None
# 23366  8/23, Монолитный  наземная
# 23367   6/23, Панельный      None
#
#                                                     Цена  ...  \
# 11     100000.0 руб./ За месяц, Залог - 110000 руб., ...  ...
# 48     90000.0 руб./ За месяц, Залог - 90000 руб., Ср...  ...
# 53     120000.0 руб./ За месяц, Залог - 120000 руб., ...  ...
# 80     120000.0 руб./ За месяц, Залог - 120000 руб., ...  ...
# 81     130000.0 руб./ За месяц, Залог - 130000 руб., ...  ...
# ...                                                  ...  ...
# 23360  42000.0 руб./ За месяц, Залог - 42000 руб., Ко...  ...
# 23361  35000.0 руб./ За месяц, Залог - 35000 руб., Ко...  ...
# 23364  45000.0 руб./ За месяц, Залог - 45000 руб., Ко...  ...
# 23366  55000.0 руб./ За месяц, Залог - 50000 руб., Ко...  ...
# 23367  57000.0 руб./ За месяц, Залог - 60000 руб., Ко...  ...
#
#                      Лифт Мусоропровод  \
# 11               Пасс (1)         None
# 48               Пасс (1)         None
# 53               Пасс (1)         None
# 80               Пасс (1)         None
# 81               Пасс (1)         None
# ...                   ...          ...
# 23360  Пасс (1), Груз (1)           Да
# 23361            Пасс (1)           Да
# 23364  Пасс (1), Груз (1)         None
# 23366            Пасс (3)           Да
# 23367            Пасс (3)           Да
#
#                           Ссылка на объявление     price total_area  \
# 11     https://www.cian.ru/rent/flat/273999490  100000.0       80.0
# 48     https://www.cian.ru/rent/flat/271265359   90000.0       60.0
# 53     https://www.cian.ru/rent/flat/273779074  120000.0       60.0
# 80     https://www.cian.ru/rent/flat/274528249  120000.0       45.0
# 81     https://www.cian.ru/rent/flat/274431438  130000.0       65.0
# ...                                        ...       ...        ...
# 23360  https://www.cian.ru/rent/flat/274905391   42000.0       39.0
# 23361  https://www.cian.ru/rent/flat/202336163   35000.0       32.0
# 23364  https://www.cian.ru/rent/flat/274654844   45000.0       38.7
# 23366  https://www.cian.ru/rent/flat/274807525   55000.0       52.5
# 23367  https://www.cian.ru/rent/flat/274672243   57000.0       90.0
#
#       rooms_clean lift_count floor total_floors area_numeric
# 11            3.0        1.0   4.0          8.0         80.0
# 48            2.0        1.0   5.0          6.0         60.0
# 53            2.0        1.0   3.0          6.0         60.0
# 80            1.0        1.0   6.0          7.0         45.0
# 81            3.0        1.0   7.0          7.0         65.0
# ...           ...        ...   ...          ...          ...
# 23360         1.0        1.0  12.0         17.0         39.0
# 23361         1.0        1.0   9.0          9.0         32.0
# 23364         1.0        1.0   5.0         18.0         38.7
# 23366         2.0        3.0   8.0         23.0         52.5
# 23367         2.0        3.0   6.0         23.0         90.0
#
# [14811 rows x 32 columns]

# %%
df = df.drop_duplicates()

# %%
print(f"Количество объявлений: {df.shape[0]:,}")
print(f"Количество характеристик: {df.shape[1]}")
# Out:
# Количество объявлений: 23,368
# Количество характеристик: 25

# %%
# ПРЕДВАРИТЕЛЬНАЯ ПОДГОТОВКА ДАННЫХ ДЛЯ ПРОВЕРКИ ВЫБРОСОВ
print("ПОДГОТОВКА ДАННЫХ ДЛЯ ПРОВЕРКИ ВЫБРОСОВ:")
print("=" * 25)

# Создаем необходимые столбцы для анализа выбросов
df['price'] = df['Цена'].str.extract('(\d+)').astype(float)
df['total_area'] = df['Площадь, м2'].astype(str).str.split('/').str[0].str.extract('(\d+\.?\d*)').astype(float)
df['rooms_clean'] = df['Количество комнат'].astype(str).str.extract('(\d+)').astype(float)

# Извлекаем количество лифтов
if 'Лифт' in df.columns:
    df['lift_count'] = df['Лифт'].str.extract('(\d+)').astype(float)

print("Созданные столбцы для анализа:")
print(f"  price: {df['price'].notna().sum()} значений")
print(f"  total_area: {df['total_area'].notna().sum()} значений") 
print(f"  rooms_clean: {df['rooms_clean'].notna().sum()} значений")
if 'lift_count' in df.columns:
    print(f"  lift_count: {df['lift_count'].notna().sum()} значений")

# ПРОВЕРКА И ФИЛЬТРАЦИЯ ВЫБРОСОВ
print("\nПРОВЕРКА НА ВЫБРОСЫ:")
print("=" * 25)

# 1. Анализ выбросов в цене
print("1. Анализ выбросов в цене:")
Q1_price = df['price'].quantile(0.25)
Q3_price = df['price'].quantile(0.75)
IQR_price = Q3_price - Q1_price
lower_bound_price = max(0, Q1_price - 1.5 * IQR_price)  # Цена не может быть отрицательной
upper_bound_price = Q3_price + 1.5 * IQR_price

outliers_price = df[(df['price'] < lower_bound_price) | (df['price'] > upper_bound_price)]
print(f"   Выбросы по цене: {len(outliers_price)} записей")
print(f"   Диапазон нормальных цен: {lower_bound_price:,.0f} - {upper_bound_price:,.0f} руб.")
if len(outliers_price) > 0:
    print("   Примеры выбросов по цене:")
    print(outliers_price[['price', 'total_area', 'rooms_clean']].head())

# 2. Анализ выбросов в площади
print("\n2. Анализ выбросов в площади:")
Q1_area = df['total_area'].quantile(0.25)
Q3_area = df['total_area'].quantile(0.75)
IQR_area = Q3_area - Q1_area
upper_bound_area = Q3_area + 1.5 * IQR_area

outliers_area = df[df['total_area'] > upper_bound_area]
print(f"   Выбросы по площади: {len(outliers_area)} записей")
print(f"   Максимальная нормальная площадь: {upper_bound_area:.1f} м²")
if len(outliers_area) > 0:
    print("   Примеры выбросов по площади:")
    print(outliers_area[['total_area', 'price', 'rooms_clean']].head())

# 3. Анализ выбросов в количестве комнат
print("\n3. Анализ выбросов в количестве комнат:")
room_outliers = df[(df['rooms_clean'] == 0) | (df['rooms_clean'] > 10)]
print(f"   Подозрительные значения комнат: {len(room_outliers)} записей")
if len(room_outliers) > 0:
    print("   Примеры подозрительных значений комнат:")
    print(room_outliers[['rooms_clean', 'price', 'total_area']].head())

# 4. Анализ выбросов в лифтах
print("\n4. Анализ выбросов в лифтах:")
if 'lift_count' in df.columns:
    lift_outliers = df[df['lift_count'] > 10]  # Более 10 лифтов - подозрительно
    print(f"   Подозрительные значения лифтов: {len(lift_outliers)} записей")
    if len(lift_outliers) > 0:
        print("   Примеры выбросов по лифтам:")
        print(lift_outliers[['Лифт', 'lift_count', 'price', 'total_area']].head())

# 5. Анализ выбросов в высоте потолков
print("\n5. Анализ выбросов в высоте потолков:")
if 'Высота потолков, м' in df.columns:
    ceiling_outliers = df[(df['Высота потолков, м'] < 2) | (df['Высота потолков, м'] > 5)]
    print(f"   Подозрительные значения высоты потолков: {len(ceiling_outliers)} записей")
    if len(ceiling_outliers) > 0:
        print("   Примеры выбросов по высоте потолков:")
        print(ceiling_outliers[['Высота потолков, м', 'price', 'total_area']].head())

# ВИЗУАЛИЗАЦИЯ ВЫБРОСОВ
plt.figure(figsize=(15, 10))

plt.subplot(2, 3, 1)
plt.boxplot(df['price'].dropna())
plt.title('Выбросы в цене')

plt.subplot(2, 3, 2)
plt.boxplot(df['total_area'].dropna())
plt.title('Выбросы в площади')

plt.subplot(2, 3, 3)
plt.boxplot(df['rooms_clean'].dropna())
plt.title('Выбросы в количестве комнат')

if 'lift_count' in df.columns and df['lift_count'].notna().sum() > 0:
    plt.subplot(2, 3, 4)
    plt.boxplot(df['lift_count'].dropna())
    plt.title('Выбросы в количестве лифтов')

if 'Высота потолков, м' in df.columns and df['Высота потолков, м'].notna().sum() > 0:
    plt.subplot(2, 3, 5)
    plt.boxplot(df['Высота потолков, м'].dropna())
    plt.title('Выбросы в высоте потолков')

plt.tight_layout()
plt.show()

# ФИЛЬТРАЦИЯ ВЫБРОСОВ
print("\nФИЛЬТРАЦИЯ ВЫБРОСОВ:")
print("=" * 25)

# Сохраняем исходное количество записей
original_count = len(df)

# Создаем маску для фильтрации
mask = (
    (df['price'] >= lower_bound_price) & 
    (df['price'] <= upper_bound_price) &
    (df['total_area'] <= upper_bound_area) &
    (df['rooms_clean'] >= 1) & 
    (df['rooms_clean'] <= 10)
)

# Дополнительная фильтрация лифтов
if 'lift_count' in df.columns:
    mask = mask & (df['lift_count'] <= 10)

# Применяем фильтрацию
df_clean = df[mask]

print(f"Исходное количество записей: {original_count}")
print(f"После фильтрации выбросов: {len(df_clean)}")
print(f"Удалено записей: {original_count - len(df_clean)} ({((original_count - len(df_clean))/original_count)*100:.1f}%)")

# РАБОТАЕМ С ОЧИЩЕННЫМИ ДАННЫМИ
df = df_clean.copy()

print("\n" + "="*50)
print("ДАЛЬНЕЙШИЕ АНАЛИЗЫ БУДУТ НА ОЧИЩЕННЫХ ДАННЫХ")
print("="*50)
# Out:
# ПОДГОТОВКА ДАННЫХ ДЛЯ ПРОВЕРКИ ВЫБРОСОВ:
# =========================
# Созданные столбцы для анализа:
#   price: 23368 значений
#   total_area: 23368 значений
#   rooms_clean: 22327 значений
#   lift_count: 17868 значений
#
# ПРОВЕРКА НА ВЫБРОСЫ:
# =========================
# 1. Анализ выбросов в цене:
#    Выбросы по цене: 2913 записей
#    Диапазон нормальных цен: 0 - 132,000 руб.
#    Примеры выбросов по цене:
#       price  total_area  rooms_clean
# 0  500000.0       200.0          4.0
# 1  500000.0       198.0          4.0
# 2  500000.0       200.0          4.0
# 3  400000.0       170.0          4.0
# 4  225000.0        58.0          2.0
#
# 2. Анализ выбросов в площади:
#    Выбросы по площади: 2079 записей
#    Максимальная нормальная площадь: 118.0 м²
#    Примеры выбросов по площади:
#    total_area     price  rooms_clean
# 0       200.0  500000.0          4.0
# 1       198.0  500000.0          4.0
# 2       200.0  500000.0          4.0
# 3       170.0  400000.0          4.0
# 6       213.0  350000.0          5.0
#
# 3. Анализ выбросов в количестве комнат:
#    Подозрительные значения комнат: 0 записей
#
# 4. Анализ выбросов в лифтах:
#    Подозрительные значения лифтов: 4 записей
#    Примеры выбросов по лифтам:
#             Лифт  lift_count     price  total_area
# 4829   Пасс (60)        60.0  220000.0        60.0
# 10584  Пасс (50)        50.0  220000.0        64.0
# 10586  Пасс (50)        50.0  230000.0        60.0
# 10623  Пасс (60)        60.0  650000.0       110.0
#
# 5. Анализ выбросов в высоте потолков:
#    Подозрительные значения высоты потолков: 32 записей
#    Примеры выбросов по высоте потолков:
#      Высота потолков, м     price  total_area
# 9                 310.0  210000.0        90.0
# 110                 5.5  145000.0        94.0
# 247               260.0   32000.0        38.0
# 757                 6.0  380000.0       120.0
# 838                 6.0  120000.0        59.0
# ФИЛЬТРАЦИЯ ВЫБРОСОВ:
# =========================
# Исходное количество записей: 23368
# После фильтрации выбросов: 14811
# Удалено записей: 8557 (36.6%)
#
# ==================================================
# ДАЛЬНЕЙШИЕ АНАЛИЗЫ БУДУТ НА ОЧИЩЕННЫХ ДАННЫХ
# ==================================================

# %%
missing_data = df.isnull().sum()
missing_percent = (missing_data / len(df)) * 100

missing_df = pd.DataFrame({
    'Колонка': missing_data.index,
    'Пропущено': missing_data.values,
    'Процент': missing_percent.values
}).sort_values('Пропущено', ascending=False)

print("АНАЛИЗ ПРОПУЩЕННЫХ ЗНАЧЕНИЙ:")
print(missing_df[missing_df['Пропущено'] > 0])

plt.figure(figsize=(12, 8))
missing_plot = missing_df[missing_df['Пропущено'] > 0]
plt.barh(missing_plot['Колонка'], missing_plot['Процент'])
plt.xlabel('Процент пропусков (%)')
plt.title('Распределение пропущенных значений по колонкам')
plt.tight_layout()
plt.savefig('img/analiz_none')
plt.show()
# Out:
# АНАЛИЗ ПРОПУЩЕННЫХ ЗНАЧЕНИЙ:
#                      Колонка  Пропущено    Процент
# 20                Серия дома      13472  90.959422
# 19               Название ЖК      11783  79.555736
# 8                   Парковка       8496  57.362771
# 21        Высота потолков, м       6686  45.142124
# 13        Площадь комнат, м2       4713  31.820944
# 23              Мусоропровод       4479  30.241037
# 14                    Балкон       4002  27.020458
# 15                      Окна       3860  26.061711
# 17  Можно с детьми/животными       3770  25.454054
# 16                   Санузел       1481   9.999325
# 12                    Ремонт       1352   9.128351
# 4                      Метро        615   4.152319
# 18             Дополнительно        156   1.053271

# %%
print("АНАЛИЗ ЦЕН:")
print("=" * 25)

df['price'] = df['Цена'].str.extract('(\d+)').astype(float)

min_price = df['price'].min()
max_price = df['price'].max() 
avg_price = df['price'].mean()
mid_price = df['price'].median()

print(f"🔢 Основные цифры:")
print(f"   Самая дешевая: {min_price:,.0f} руб.")
print(f"   Самая дорогая: {max_price:,.0f} руб.")
print(f"   В среднем: {avg_price:,.0f} руб.")
print(f"   Типичная цена: {mid_price:,.0f} руб.")

plt.figure(figsize=(8, 4))
plt.hist(df['price'].dropna(), bins=15, color='orange', alpha=0.7)
plt.title('Сколько квартир по каким ценам')
plt.xlabel('Цена аренды (руб)')
plt.ylabel('Количество квартир')
plt.savefig('img/prices_vs_apartamets')
plt.show()
# Out:
# АНАЛИЗ ЦЕН:
# =========================
# 🔢 Основные цифры:
#    Самая дешевая: 10,000 руб.
#    Самая дорогая: 130,800 руб.
#    В среднем: 52,037 руб.
#    Типичная цена: 45,000 руб.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))


ax1.hist(df['price'].dropna(), bins=25, color='lightblue', alpha=0.8)
ax1.set_title('Распределение цен на аренду')
ax1.set_xlabel('Цена (руб.)')
ax1.set_ylabel('Количество')

ax2.boxplot(df['price'].dropna())
ax2.set_title('Разброс цен (Boxplot)')
ax2.set_ylabel('Цена (руб.)')

plt.tight_layout()
plt.savefig('img/rental_prices')
plt.show()

print("Вывод: Большинство квартир стоят в диапазоне {}-{} руб.".format(
    df['price'].quantile(0.25), 
    df['price'].quantile(0.75)
))
# Out:
# Вывод: Большинство квартир стоят в диапазоне 36000.0-60000.0 руб.

# %%
categorical_columns = ['Количество комнат', 'Тип', 'Ремонт', 'Парковка']

fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.ravel()

for i, col in enumerate(categorical_columns):
    if col in df.columns:
        value_counts = df[col].value_counts().head(10)
        axes[i].bar(value_counts.index.astype(str), value_counts.values)
        axes[i].set_title(f'Распределение: {col}')
        axes[i].tick_params(axis='x', rotation=45)
        
        total = len(df[col].dropna())
        for j, v in enumerate(value_counts.values):
            axes[i].text(j, v, f'{v/total*100:.1f}%', 
                        ha='center', va='bottom')

plt.tight_layout()
plt.savefig('img/some_graphs')
plt.show()

# %%
print("АНАЛИЗ РАСПРЕДЕЛЕНИЯ ПО МЕТРО:")
metro_counts = df['Метро'].value_counts().head(10)
print(metro_counts)

plt.figure(figsize=(12, 6))
metro_counts.plot(kind='barh', color='lightblue')
plt.title('Топ-10 станций метро по количеству объявлений')
plt.xlabel('Количество объявлений')
plt.tight_layout()
plt.savefig('img/metro')
plt.show()
# Out:
# АНАЛИЗ РАСПРЕДЕЛЕНИЯ ПО МЕТРО:
# Метро
# м. Строгино (15 мин пешком)              31
# м. Римская (None мин пешком)             30
# м. Октябрьское поле (4 мин на машине)    28
# м. Водный стадион (5 мин пешком)         27
# м. Щелковская (15 мин пешком)            27
# м. Академическая (10 мин пешком)         26
# м. Царицыно (10 мин на машине)           25
# м. Коломенская (15 мин пешком)           25
# м. Селигерская (15 мин пешком)           24
# м. Щелковская (4 мин на машине)          22
# Name: count, dtype: int64

# %%
def extract_area(area_str):
    if pd.isna(area_str):
        return np.nan
    if isinstance(area_str, str):
        parts = area_str.split('/')
        if parts:
            try:
                return float(parts[0])
            except:
                return np.nan
    return np.nan

df['area_numeric'] = df['Площадь, м2'].apply(extract_area)

plt.figure(figsize=(12, 6))
plt.scatter(df['area_numeric'], df['price'], alpha=0.6, color='purple')
plt.xlabel('Площадь (м²)')
plt.ylabel('Цена (руб.)')
plt.title('Зависимость цены от площади')
plt.grid(True, alpha=0.3)

plt.savefig('img/price_distribution')
plt.show()

# %%
df['floor'] = df['Дом'].str.extract(r'(\d+)/\d+').astype(float)
df['total_floors'] = df['Дом'].str.extract(r'/(\d+)').astype(float)

print(f"Этажи: {df['floor'].min():.0f}-{df['floor'].max():.0f}")
print(f"Этажность: {df['total_floors'].min():.0f}-{df['total_floors'].max():.0f}")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.hist(df['floor'].dropna(), bins=15, color='lightblue', alpha=0.7)
ax1.set_title('На каких этажах квартиры')
ax1.set_xlabel('Этаж')
ax1.set_ylabel('Количество')

ax2.hist(df['total_floors'].dropna(), bins=10, color='lightgreen', alpha=0.7)
ax2.set_title('Этажность домов')
ax2.set_xlabel('Этажность')
ax2.set_ylabel('Количество')

plt.tight_layout()
plt.savefig('img/floors')
plt.show()
# Out:
# Этажи: 1-42
# Этажность: 3-60

# %%
print("Варианты окон:")
print(df['Окна'].value_counts())

plt.figure(figsize=(10, 4))

window_counts = df['Окна'].value_counts().head(8)  

plt.barh(window_counts.index.astype(str), window_counts.values, color='orange', alpha=0.7)
plt.title('Куда выходят окна')
plt.xlabel('Количество квартир')
plt.tight_layout()
plt.show()
plt.savefig('img/windows')

print(f"Самый частый вариант: {window_counts.index[0]}")
# Out:
# Варианты окон:
# Окна
# Во двор            7537
# На улицу и двор    1715
# На улицу           1699
# Name: count, dtype: int64
# Самый частый вариант: Во двор

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.scatter(df['floor'], df['price'], alpha=0.5, color='blue')
ax1.set_title('Цена vs Этаж')
ax1.set_xlabel('Этаж')
ax1.set_ylabel('Цена (руб)')

top_windows = df['Окна'].value_counts().head(5).index
window_prices = df[df['Окна'].isin(top_windows)].groupby('Окна')['price'].mean()

ax2.barh(window_prices.index.astype(str), window_prices.values, color='orange', alpha=0.7)
ax2.set_title('Средняя цена по типу окон')
ax2.set_xlabel('Средняя цена (руб)')

plt.tight_layout()
plt.savefig('img/price_vs_floors')
plt.show()

# %%
print("\nКОРРЕЛЯЦИОННЫЙ АНАЛИЗ:")
print("=" * 25)

corr_data = df[['price', 'total_area', 'rooms_clean']].copy()

correlation_matrix = corr_data.corr()

print("Матрица корреляций:")
print(correlation_matrix)

print("\nКорреляция с ценой:")
print(f"  С площадью: {correlation_matrix.loc['price', 'total_area']:.3f}")
print(f"  С количеством комнат: {correlation_matrix.loc['price', 'rooms_clean']:.3f}")

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Корреляция между ценой, площадью и комнатами')
plt.show()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

ax1.scatter(df['total_area'], df['price'], alpha=0.5)
ax1.set_xlabel('Площадь (м²)')
ax1.set_ylabel('Цена (руб)')
ax1.set_title('Цена vs Площадь')

ax2.scatter(df['rooms_clean'], df['price'], alpha=0.5)
ax2.set_xlabel('Количество комнат')
ax2.set_ylabel('Цена (руб)')
ax2.set_title('Цена vs Комнаты')

plt.tight_layout()
plt.show()
# Out:
# КОРРЕЛЯЦИОННЫЙ АНАЛИЗ:
# =========================
# Матрица корреляций:
#                 price  total_area  rooms_clean
# price        1.000000    0.681198     0.565952
# total_area   0.681198    1.000000     0.809508
# rooms_clean  0.565952    0.809508     1.000000
#
# Корреляция с ценой:
#   С площадью: 0.681
#   С количеством комнат: 0.566
